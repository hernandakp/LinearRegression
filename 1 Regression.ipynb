# %%
'Author: hernanda472@gmail.com'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
import warnings

# %%
df = pd.read_csv('1 Dataset.csv')
df
# Out:
#      Fisrt_Name Last_Name Gender        Age  Length_Service  Absent_Hours  \
# 0     Gutierrez     Molly      F  32.028816        6.018478     36.577306
# 1      Hardwick   Stephen      M  40.320902        5.532445     30.165072
# 2       Delgado   Chester      M  48.822047        4.389973     83.807798
# 3         Simon     Irene      F  44.599357        3.081736     70.020165
# 4      Delvalle    Edward      M  35.697876        3.619091      0.000000
# ...         ...       ...    ...        ...             ...           ...
# 8331   Coniglio    Bianca      F  46.057544        4.838288     93.665111
# 8332        Cox    Jimmie      M  34.455490        2.427274      0.000000
# 8333    Hawkins      Mary      F  58.347160        4.009393    176.356940
# 8334    Proctor   Theresa      F  43.340616        6.154837     60.321917
# 8335     Salter   Charles      M  46.192782        5.174722    112.023389
#
#       distribution_centers_id
# 0                           5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8336 entries, 0 to 8335
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Fisrt_Name               8336 non-null   object
#  1   Last_Name                8336 non-null   object
#  2   Gender                   8336 non-null   object
#  3   Age                      8336 non-null   float64
#  4   Length_Service           8336 non-null   float64
#  5   Absent_Hours             8336 non-null   float64
#  6   distribution_centers_id  8336 non-null   int64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 456.0+ KB

# %%
df.describe()
# Out:
#                Age  Length_Service  Absent_Hours  distribution_centers_id
# count  8336.000000     8336.000000   8336.000000              8336.000000
# mean     42.007086        4.782910     61.283978                 5.493762
# std       9.939798        2.462990     49.038365                 2.872447
# min       3.504743        0.012098      0.000000                 1.000000
# 25%      35.298748        3.575892     19.127590                 3.000000
# 50%      42.114924        4.600248     56.005808                 5.000000
# 75%      48.666943        5.623922     94.284692                 8.000000
# max      77.938003       43.735239    272.530123                10.000000

# %% [markdown]
# **Detect and Remove the Outliers**

# %%
# Age

warnings.filterwarnings('ignore')
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['Age'])
plt.show()

# %%
print("Highest allowed",df['Age'].mean() + 3*df['Age'].std())
print("Lowest allowed",df['Age'].mean() - 3*df['Age'].std())
# Out:
# Highest allowed 71.8264794145752
# Lowest allowed 12.187691962824744

# %%
new = df[(df['Age'] < 71.8264794145752) & (df['Age'] > 12.187691962824744)]
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(new['Age'])
plt.show()

# %%
# Length_Service

plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['Length_Service'])
plt.show()

# %%
print("Highest allowed",df['Length_Service'].mean() + 3*df['Length_Service'].std())
print("Lowest allowed",df['Length_Service'].mean() - 3*df['Length_Service'].std())
# Out:
# Highest allowed 12.171878205013286
# Lowest allowed -2.606059075434829

# %%
new = df[(df['Length_Service'] < 12.171878205013286) & (df['Length_Service'] > -2.606059075434829)]
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(new['Length_Service'])
plt.show()

# %%
# Absent_Hours

plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['Absent_Hours'])
plt.show()

# %%
print("Highest allowed",df['Absent_Hours'].mean() + 3*df['Absent_Hours'].std())
print("Lowest allowed",df['Absent_Hours'].mean() - 3*df['Absent_Hours'].std())
# Out:
# Highest allowed 208.39907144829175
# Lowest allowed -85.83111608306046

# %%
new = df[(df['Absent_Hours'] < 208.39907144829175) & (df['Absent_Hours'] > -85.83111608306046)]
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(new['Absent_Hours'])
plt.show()

# %%
# distribution_centers_id

plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['distribution_centers_id'])
plt.show()

# %%
print("Highest allowed",df['distribution_centers_id'].mean() + 3*df['distribution_centers_id'].std())
print("Lowest allowed",df['distribution_centers_id'].mean() - 3*df['distribution_centers_id'].std())
# Out:
# Highest allowed 14.111102534988273
# Lowest allowed -3.1235785426658156

# %%
new = df[(df['distribution_centers_id'] < 14.111102534988273) & (df['distribution_centers_id'] > -3.1235785426658156)]
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(new['distribution_centers_id'])
plt.show()

# %%
new
# Out:
#      Fisrt_Name Last_Name Gender        Age  Length_Service  Absent_Hours  \
# 0     Gutierrez     Molly      F  32.028816        6.018478     36.577306
# 1      Hardwick   Stephen      M  40.320902        5.532445     30.165072
# 2       Delgado   Chester      M  48.822047        4.389973     83.807798
# 3         Simon     Irene      F  44.599357        3.081736     70.020165
# 4      Delvalle    Edward      M  35.697876        3.619091      0.000000
# ...         ...       ...    ...        ...             ...           ...
# 8331   Coniglio    Bianca      F  46.057544        4.838288     93.665111
# 8332        Cox    Jimmie      M  34.455490        2.427274      0.000000
# 8333    Hawkins      Mary      F  58.347160        4.009393    176.356940
# 8334    Proctor   Theresa      F  43.340616        6.154837     60.321917
# 8335     Salter   Charles      M  46.192782        5.174722    112.023389
#
#       distribution_centers_id
# 0                           5
# ...

# %% [markdown]
# **a. Regresi antara age dengan Absent_Hours**

# %%
# Encode data
X = new['Age'].values
Y = new['Absent_Hours'].values

# Regresi Metode Least-Square Linear

# Menghitung slope, intercept, dan nilai rata-rata
X_avg = np.average(X)
Y_avg = np.average(Y)
X_mean = np.mean(X)
Y_mean = np.mean(Y)
num = 0
den = 0
for i in range(len(X)):
  num += (X[i] -  X_mean)*(Y[i] - Y_mean)
  den += (X[i] - X_mean)**2
m = num/den
c = Y_mean - m*X_mean
print("Nilai yang didapat:")
print("Slope =", (m))
print("Intercept =", (c))
print("X rata-rata =", (X_avg))
print("Y rata-rata =", (Y_avg))

# Menghitung letak Y
Y_pred = m*X + c
print ("Titik Y =", Y_pred)

# Memplot grafik
plt.figure(figsize = (13, 5))
plt.title("Regresi dengan Metode Least-Square Linear")
plt.scatter(X, Y, color = "red")
plt.plot(X, Y_pred, color = "green")
plt.xlabel("Age")
plt.ylabel("Absent_Hours")
plt.show()
# Out:
# Nilai yang didapat:
# Slope = 4.095990826110512
# Intercept = -110.77665992993764
# X rata-rata = 42.00708568869997
# Y rata-rata = 61.28397768261564
# Titik Y = [ 20.41307531  54.37738341  89.1979951  ... 128.21277404  66.74610384
#   78.42855101]

# %%
# Regresi Metode Exponential Function

model = LinearRegression(fit_intercept = True)
model.fit(X[:, np.newaxis], Y)
print("Nilai yang didapat:")
print("Slope =", model.coef_)
print("Intercept =", [model.intercept_])
Y_pred = model.coef_*X + model.intercept_
print ("Titik y =", Y_pred)
plt.figure(figsize = (13, 5))
plt.plot(X, Y, color = "green")
plt.title('Regresi dengan Metode Exponential Function')
plt.xlabel("Age")
plt.ylabel("Absent_Hours")
plt.scatter(X, Y, color = 'red')
plt.show()
# Out:
# Nilai yang didapat:
# Slope = [4.09599083]
# Intercept = [-110.77665992993747]
# Titik y = [ 20.41307531  54.37738341  89.1979951  ... 128.21277404  66.74610384
#   78.42855101]

# %% [markdown]
# **b. Regresi antara Age dengan Length_Service**

# %%
# Encode data
X = new['Age'].values
Y = new['Length_Service'].values

# Regresi Metode Least-Square Linear

# Menghitung slope, intercept, dan nilai rata-rata
X_avg = np.average(X)
Y_avg = np.average(Y)
X_mean = np.mean(X)
Y_mean = np.mean(Y)
num = 0
den = 0
for i in range(len(X)):
  num += (X[i] -  X_mean)*(Y[i] - Y_mean)
  den += (X[i] - X_mean)**2
m = num/den
c = Y_mean - m*X_mean
print("Nilai yang didapat:")
print("Slope =", (m))
print("Intercept =", (c))
print("X rata-rata =", (X_avg))
print("Y rata-rata =", (Y_avg))

# Menghitung letak Y
Y_pred = m*X + c
print ("Titik Y =", Y_pred)

# Memplot grafik
plt.figure(figsize = (13, 5))
plt.title("Regresi dengan Metode Least-Square Linear")
plt.scatter(X, Y, color = "red")
plt.plot(X, Y_pred, color = "green")
plt.xlabel("Age")
plt.ylabel("Length_Service")
plt.show()
# Out:
# Nilai yang didapat:
# Slope = 0.013158800137139479
# Intercept = 4.230146719867933
# X rata-rata = 42.00708568869997
# Y rata-rata = 4.782909564789228
# Titik Y = [4.6516075  4.76072141 4.87258627 ... 4.99792534 4.80045722 4.8379883 ]

# %%
# Regresi Metode Exponential Function

model = LinearRegression(fit_intercept = True)
model.fit(X[:, np.newaxis], Y)
print("Nilai yang didapat:")
print("Slope =", model.coef_)
print("Intercept =", [model.intercept_])
Y_pred = model.coef_*X + model.intercept_
print ("Titik y =", Y_pred)
plt.figure(figsize = (13, 5))
plt.plot(X, Y, color = "green")
plt.title('Regresi dengan Metode Exponential Function')
plt.xlabel("Age")
plt.ylabel("Length_Service")
plt.scatter(X, Y, color = 'red')
plt.show()
# Out:
# Nilai yang didapat:
# Slope = [0.0131588]
# Intercept = [4.230146719867933]
# Titik y = [4.6516075  4.76072141 4.87258627 ... 4.99792534 4.80045722 4.8379883 ]

# %% [markdown]
# **c. Regresi antara Age dengan distribution_centers_id**

# %%
# Encode data
X = new['Age'].values
Y = new['distribution_centers_id'].values

# Regresi Metode Least-Square Linear

# Menghitung slope, intercept, dan nilai rata-rata
X_avg = np.average(X)
Y_avg = np.average(Y)
X_mean = np.mean(X)
Y_mean = np.mean(Y)
num = 0
den = 0
for i in range(len(X)):
  num += (X[i] -  X_mean)*(Y[i] - Y_mean)
  den += (X[i] - X_mean)**2
m = num/den
c = Y_mean - m*X_mean
print("Nilai yang didapat:")
print("Slope =", (m))
print("Intercept =", (c))
print("X rata-rata =", (X_avg))
print("Y rata-rata =", (Y_avg))

# Menghitung letak Y
Y_pred = m*X + c
print ("Titik Y =", Y_pred)

# Memplot grafik
plt.figure(figsize = (13, 5))
plt.title("Regresi dengan Metode Least-Square Linear")
plt.scatter(X, Y, color = "red")
plt.plot(X, Y_pred, color = "green")
plt.xlabel("age")
plt.ylabel("distribution_centers_id")
plt.show()
# Out:
# Nilai yang didapat:
# Slope = -0.004498500337364548
# Intercept = 5.682730885303546
# X rata-rata = 42.00708568869997
# Y rata-rata = 5.493761996161228
# Titik Y = [5.53864925 5.5013473  5.46310489 ... 5.42025616 5.48776311 5.47493264]

# %%
# Regresi Metode Exponential Function

model = LinearRegression(fit_intercept = True)
model.fit(X[:, np.newaxis], Y)
print("Nilai yang didapat:")
print("Slope =", model.coef_)
print("Intercept =", [model.intercept_])
Y_pred = model.coef_*X + model.intercept_
print ("Titik y =", Y_pred)
plt.figure(figsize = (13, 5))
plt.plot(X, Y, color = "green")
plt.title('Regresi dengan Metode Exponential Function')
plt.xlabel("age")
plt.ylabel("distribution_centers_id")
plt.scatter(X, Y, color = 'red')
plt.show()
# Out:
# Nilai yang didapat:
# Slope = [-0.0044985]
# Intercept = [5.682730885303546]
# Titik y = [5.53864925 5.5013473  5.46310489 ... 5.42025616 5.48776311 5.47493264]

# %% [markdown]
# **d. Regresi antara Length_Service dengan Absent_Hours**

# %%
# Encode data
X = new['Length_Service'].values
Y = new['Absent_Hours'].values

# Regresi Metode Least-Square Linear

# Menghitung slope, intercept, dan nilai rata-rata
X_avg = np.average(X)
Y_avg = np.average(Y)
X_mean = np.mean(X)
Y_mean = np.mean(Y)
num = 0
den = 0
for i in range(len(X)):
  num += (X[i] -  X_mean)*(Y[i] - Y_mean)
  den += (X[i] - X_mean)**2
m = num/den
c = Y_mean - m*X_mean
print("Nilai yang didapat:")
print("Slope =", (m))
print("Intercept =", (c))
print("X rata-rata =", (X_avg))
print("Y rata-rata =", (Y_avg))

# Menghitung letak Y
Y_pred = m*X + c
print ("Titik Y =", Y_pred)

# Memplot grafik
plt.figure(figsize = (13, 5))
plt.title("Regresi dengan Metode Least-Square Linear")
plt.scatter(X, Y, color = "red")
plt.plot(X, Y_pred, color = "green")
plt.xlabel("Length_Service")
plt.ylabel("Absent_Hours")
plt.show()
# Out:
# Nilai yang didapat:
# Slope = -0.8800576872457136
# Intercept = 65.49321401250945
# X rata-rata = 4.782909564789228
# Y rata-rata = 61.28397768261564
# Titik Y = [60.19660577 60.62434363 61.62978442 ... 61.96471725 60.07660266
#  60.93916039]

# %%
# Regresi Metode Exponential Function

model = LinearRegression(fit_intercept = True)
model.fit(X[:, np.newaxis], Y)
print("Nilai yang didapat:")
print("Slope =", model.coef_)
print("Intercept =", [model.intercept_])
Y_pred = model.coef_*X + model.intercept_
print ("Titik y =", Y_pred)
plt.figure(figsize = (13, 5))
plt.plot(X, Y, color = "green")
plt.title('Regresi dengan Metode Exponential Function')
plt.xlabel("Length_Service")
plt.ylabel("Absent_Hours")
plt.scatter(X, Y, color = 'red')
plt.show()
# Out:
# Nilai yang didapat:
# Slope = [-0.88005769]
# Intercept = [65.49321401250941]
# Titik y = [60.19660577 60.62434363 61.62978442 ... 61.96471725 60.07660266
#  60.93916039]

# %% [markdown]
# **e. Korelasi antar variabel**

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(15,15))
plt.title('Pearson Correlation of Features', y=1.0, size=10)
sns.heatmap(new.corr(),linewidths=0.2,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %% [markdown]
# **f. Perbedaan M dan F**

# %%
plt.figure(figsize=(15,9))
sns.kdeplot(new.Absent_Hours[new.Gender=='M'], label='men', shade=True)
sns.kdeplot(new.Absent_Hours[new.Gender=='F'], label='women', shade=True)
plt.xlabel('Absent_Hours')
# Out:
# Text(0.5, 0, 'Absent_Hours')

# %%
average_male = new.Absent_Hours[new.Gender == 'M'].mean()
average_female = new.Absent_Hours[new.Gender == 'F'].mean()
print('Mean of absenthours for male: ', average_male)
print('Mean of absenthours for female: ', average_female)
# Out:
# Mean of absenthours for male:  56.002666466176706
# Mean of absenthours for female:  66.68834857788423

# %% [markdown]
# Heatmap matriks korelasi adalah sebuah peta yang menggambarkan persebaran lokasi dan frekuensi data dalam dengan pewarnaan yang bergradasi. Perintah ini hanya mengolah data yang bertipe integer saja. Pada heatmap ini terdapat 4 data yaitu data Age, Length_Service, Absent_Hours, dan distribution_centers_id.
#
# Korelasi merupakan salah satu teknik analisis dalam statistik yang digunakan untuk mencari hubungan antara dua variabel yang bersifat kuantitatif. Hubungan dua variabel tersebut dapat terjadi karena adanya hubungan sebab akibat atau dapat pula terjadi karena kebetulan saja. Dua variabel dikatakan berkolerasi apabila perubahan pada variabel yang satu akan diikuti perubahan pada variabel yang lain secara teratur dengan arah yang sama (korelasi positif) atau berlawanan (korelasi negatif).
#
# Dalam Matematika, korelasi merupakan ukuran dari seberapa dekat dua variabel berubah dalam hubungan satu sama lain. Sebagai contoh, kita bisa menggunakan tinggi badan dan usia siswa SD sebagai variabel dalam korelasi positif. Semakin tua usia siswa SD, maka tinggi badannya pun menjadi semakin tinggi. Hubungan ini disebut korelasi positif karena kedua variabel mengalami perubahan ke arah yang sama, yakni dengan meningkatnya usia, maka tinggi badan pun ikut meningkat.
#
# Sementara itu, kita bisa menggunakan nilai dan tingkat ketidak hadiran siswa sebagai contoh dalam korelasi negatif. Semakin tinggi tingkat ketidak hadiran siswa di kelas, maka nilai yang diperolehnya cenderung semakin rendah. Hubungan ini disebut korelasi negatif karena kedua variabel mengalami perubahan ke arah yang berlawanan, yakni dengan meningkatnya tingkat ketidak hadiran, maka nilai siswa justru menurun.
#
# Kedua variabel yang dibandingkan satu sama lain dalam korelasi dapat dibedakan menjadi variabel independen dan variabel dependen. Sesuai dengan namanya, variabel independen adalah variabel yang perubahannya cenderung di luar kendali manusia. Sementara itu variabel dependen adalah variabel yang dapat berubah sebagai akibat dari perubahan variabel indipenden. Hubungan ini dapat dicontohkan dengan ilustrasi pertumbuhan tanaman dengan variabel sinar matahari dan tinggi tanaman. Sinar matahari merupakan variabel independen karena intensitas cahaya yang dihasilkan oleh matahari tidak dapat diatur oleh manusia. Sedangkan tinggi tanaman merupakan variabel dependen karena perubahan tinggi tanaman dipengaruhi langsung oleh intensitas cahaya matahari sebagai variabel indipenden.
#
# Program regresi dengan Metode Least-Square Linear dapat memproses data yang diketahui (x dan y) yang nantinya akan  menghasilkan output nilai rata-rata X, nilai rata-rata Y, nilai slope, nilai intercept, dan titik Y. Titik-titik warna merah merupakan titik koordinat dari data yang diketahui dan garis hijau merupakan suatu fungsi yang paling sesuai untuk merepresentasikan data-data titik tersebut sebagai fungsi linear. Dalam metode least-square linear meminimalisir jumlah kuadrat error dimana data regresi membentuk hubungan y dan x dalam persamaan regresi karena data diproses berdasarkan interval pendekatan keseluruhan sesuai dengan order pendekatan yang meningkat.
#
# Program regresi dengan Metode Exponential Function adalah metode yang bertujuan untuk memproses data yang diketahui (x dan y) yang nantinya menghasilkan output nilai slope, nilai intercept, dan titik Y. Titik-titik warna merah merupakan titik koordinat dari data yang diketahui, kemudian titik-titik tersebut membentuk kurva berwarna hijau yang paling sesuai untuk merepresentasikan data titik-titik tersebut sebagai fungsi eksponensial.
#
# Kedua metode ini memiliki kelebihan dan kekurangan masing-masing pada proses pengerjaannya. Menurut saya metode least square lebih baik daripada metode eksponensial secara ilmiah. Metode least square dapat menghasilkan persamaan  yang dapat dipertanggungjawabkan secara ilmiah. Serta tidak ada data yang tidak digunakan. Walaupun metode least square memiliki sedikit kekurangan pada sistem pengerjaannya yang digunakan secara manual.
